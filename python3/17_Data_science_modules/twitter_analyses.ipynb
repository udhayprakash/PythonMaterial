# %%
import tweepy

consumer_key = 'xxxxxxxxxxxxxxxxxxxxxxx'
consumer_secret = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'
access_token = '45775278-xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'
access_token_secret = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
public_tweets = api.home_timeline()

# %%
public_tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x000000000581B608>, _json={'created_at': 'Sat Sep 14 01:30:17 +0000 2019', 'id': 1172683958187974657, 'id_str': '1172683958187974657', 'text': 'Script your own pentesting tools in python https://t.co/8yaK0A4TO9 Get comprehensive coverage of python &amp; 35+ infos… https://t.co/gdcBT0p8xo', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/8yaK0A4TO9', 'expanded_url': 'http://bit.ly/1gyrZDi', 'display_url': 'bit.ly/1gyrZDi', 'indices': [43, 66]}, {'url': 'https://t.co/gdcBT0p8xo', 'expanded_url': 'https://twitter.com/i/web/status/1172683958187974657', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}]}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 205258
# ...

# %%
from pprint import pprint

# %%
dir(public_tweets[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'possibly_sensitive',
#  'possibly_sensitive_appealable',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
# ...

# %%
public_tweets[0].text
# Out:
# 'Script your own pentesting tools in python https://t.co/8yaK0A4TO9 Get comprehensive coverage of python &amp; 35+ infos… https://t.co/gdcBT0p8xo'

# %%
public_tweets[0].source_url
# Out:
# 'https://www.hootsuite.com'

# %%
public_tweets[0].user
# Out:
# User(_api=<tweepy.api.API object at 0x000000000581B608>, _json={'id': 20525891, 'id_str': '20525891', 'name': 'Pentester Academy', 'screen_name': 'SecurityTube', 'location': 'Sunnyvale, CA', 'description': 'Comprehensive, Hands-on, Practical and Affordable infosec training. Join students from 90+ Countries:     http://t.co/QVTIJZCdlx https://t.co/ikiFmJnVQf', 'url': 'https://t.co/CtEcp9JP1W', 'entities': {'url': {'urls': [{'url': 'https://t.co/CtEcp9JP1W', 'expanded_url': 'http://www.PentesterAcademy.com/topics', 'display_url': 'PentesterAcademy.com/topics', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'http://t.co/QVTIJZCdlx', 'expanded_url': 'http://PentesterAcademy.com', 'display_url': 'PentesterAcademy.com', 'indices': [106, 128]}, {'url': 'https://t.co/ikiFmJnVQf', 'expanded_url': 'http://HackerArsenal.com', 'display_url': 'HackerArsenal.com', 'indices': [129, 152]}]}}, 'protected': False, 'followers_count': 122937, 'friends_count': 14611, 'listed_count': 2966, 'creat
# ...

# %%
user = api.get_user('twitter')

# %%
user
# Out:
# User(_api=<tweepy.api.API object at 0x000000000581B608>, _json={'id': 783214, 'id_str': '783214', 'name': 'Twitter', 'screen_name': 'Twitter', 'location': 'Everywhere', 'profile_location': None, 'description': 'What’s happening?!', 'url': 'https://t.co/TAXQpsHa5X', 'entities': {'url': {'urls': [{'url': 'https://t.co/TAXQpsHa5X', 'expanded_url': 'https://about.twitter.com/', 'display_url': 'about.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 56653140, 'friends_count': 80, 'listed_count': 90699, 'created_at': 'Tue Feb 20 14:35:54 +0000 2007', 'favourites_count': 6288, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 11701, 'lang': None, 'status': {'created_at': 'Fri Sep 13 23:49:10 +0000 2019', 'id': 1172658510925942784, 'id_str': '1172658510925942784', 'text': '@ingridoliver100 subtweet it out', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'s
# ...

# %%
print(user.screen_name)
# Out:
# Twitter

# %%
my_user = api.get_user('uday3prakash')

# %%
my_user.screen_name
# Out:
# 'uday3prakash'

# %%
my_user.followers_count
# Out:
# 42

# %%
my_user.created_at
# Out:
# datetime.datetime(2009, 6, 9, 5, 42, 13)

# %%
for friend in my_user.friends():
   print(friend.screen_name)
# Out:
# Space_Station
# frp09
# MikeHerman
# radekosmulski
# CodeWisdom
# random_forests
# DjangoConEurope
# python_tip
# HackerEarth
# geeksforgeeks
# codechef
# hackerrank
# googlecodejam
# careercup
# Topcoder
# LeetCode
# testdrivenio
# rwieruch
# achillean
# vhkprasad

# %%
# To update the status
api.update_status('tweepy + oauth!')
# Out:
# Status(_api=<tweepy.api.API object at 0x000000000581B608>, _json={'created_at': 'Sat Sep 14 01:46:43 +0000 2019', 'id': 1172688091594670080, 'id_str': '1172688091594670080', 'text': 'tweepy + oauth!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://www.tcloudtech.com" rel="nofollow">udhay prakash </a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 45775278, 'id_str': '45775278', 'name': 'Udhay Prakash Pethakamsetty', 'screen_name': 'uday3prakash', 'location': 'HYDERABAD, INDIA', 'description': 'Full Stack Developer (Python/Django/AWS /Azure Cloud), UST Global Pvt. Ltd', 'url': 'https://t.co/ImEu1z1Uxs', 'entities': {'url': {'urls': [{'url': 'https://t.co/ImEu1z1Uxs', 'expanded_url': 'http://udhayprakash.blogspot.com', 'display_url': 'udhayprakash.blogspot.com', 'indices': [0, 23]
# ...

# %%
api.update_status('Updating the twitter status, using @tweepy')
# Out:
# Status(_api=<tweepy.api.API object at 0x000000000581B608>, _json={'created_at': 'Sat Sep 14 01:47:45 +0000 2019', 'id': 1172688354254585857, 'id_str': '1172688354254585857', 'text': 'Updating the twitter status, using @tweepy', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'tweepy', 'name': 'tweepy', 'id': 14452478, 'id_str': '14452478', 'indices': [35, 42]}], 'urls': []}, 'source': '<a href="http://www.tcloudtech.com" rel="nofollow">udhay prakash </a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 45775278, 'id_str': '45775278', 'name': 'Udhay Prakash Pethakamsetty', 'screen_name': 'uday3prakash', 'location': 'HYDERABAD, INDIA', 'description': 'Full Stack Developer (Python/Django/AWS /Azure Cloud), UST Global Pvt. Ltd', 'url': 'https://t.co/ImEu1z1Uxs', 'entities': {'url': {'urls': [{'url': 'https://t.c
# ...

# %%
for follower in tweepy.Cursor(api.followers).items():
    print(follower.screen_name)
# Out:
# imkraghu
# ThePayrollEdge
# Inteqna
# 4vsKrishna
# SAMRAT4311
# kunalkoushal30
# dbk_reddy
# n14051948
# javeed45758780
# Axurez
# rk_racharla
# SeeSweden_
# ychandraj
# kishoreo
# geeskol
# physicsnutshell
# Chandrahasa_
# 88sreelaxmi
# nishi04may07
# virupaksharamc1
# gurralaupender1
# zeusvik
# RakeshVarudu
# boga_sushanth
# venkatamanikant
# fidelng
# kapilgangadhar
# PSaggurthi
# rao_23
# nagiitkgp
# vadityasankar3
# 430Anusha
# DasariPraveen
# 438Sudha
# PranithBirudula
# laxmiramajagan
# trustoncctv
# reddy472
# BharathGvb
# ganesh_anand
# chvijay755
# pavannvn

# %%
api.retweets_of_me()
# Out:
# []

# %%
public_tweets[0].id
# Out:
# 1172683958187974657

# %%
api.retweet(public_tweets[0].id)
# Out:
# Status(_api=<tweepy.api.API object at 0x000000000581B608>, _json={'created_at': 'Sat Sep 14 01:57:04 +0000 2019', 'id': 1172690696278462465, 'id_str': '1172690696278462465', 'text': 'RT @SecurityTube: Script your own pentesting tools in python https://t.co/8yaK0A4TO9 Get comprehensive coverage of python &amp; 35+ infosec cou…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SecurityTube', 'name': 'Pentester Academy', 'id': 20525891, 'id_str': '20525891', 'indices': [3, 16]}], 'urls': [{'url': 'https://t.co/8yaK0A4TO9', 'expanded_url': 'http://bit.ly/1gyrZDi', 'display_url': 'bit.ly/1gyrZDi', 'indices': [61, 84]}]}, 'source': '<a href="http://www.tcloudtech.com" rel="nofollow">udhay prakash </a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 45775278, 'id_str': '45775278', 'name': 'Udhay Prakash Pethakams
# ...

# %%
retweets_of_a_tweet = api.retweets(public_tweets[0].id)

# %%
retweets_of_a_tweet
# Out:
# [Status(_api=<tweepy.api.API object at 0x000000000581B608>, _json={'created_at': 'Sat Sep 14 01:57:04 +0000 2019', 'id': 1172690696278462465, 'id_str': '1172690696278462465', 'text': 'RT @SecurityTube: Script your own pentesting tools in python https://t.co/8yaK0A4TO9 Get comprehensive coverage of python &amp; 35+ infosec cou…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SecurityTube', 'name': 'Pentester Academy', 'id': 20525891, 'id_str': '20525891', 'indices': [3, 16]}], 'urls': [{'url': 'https://t.co/8yaK0A4TO9', 'expanded_url': 'http://bit.ly/1gyrZDi', 'display_url': 'bit.ly/1gyrZDi', 'indices': [61, 84]}]}, 'source': '<a href="http://www.tcloudtech.com" rel="nofollow">udhay prakash </a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 45775278, 'id_str': '45775278', 'name': 'Udhay Prakash Pethakam
# ...

# %%
dir(retweets_of_a_tweet[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'possibly_sensitive',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'retweets',
#  'source',
# ...

# %%
retweets_of_a_tweet[0].user.screen_name
# Out:
# 'uday3prakash'

# %%
retweets_of_a_tweet[1].user.screen_name
# Out:
# 'magotrox'

# %%
retweets_of_a_tweet[2].user.screen_name
# Out:
# 'cyberpunkflxer'

# %%
realDonaldTrump = api.get_user('realDonaldTrump')

# %%
realDonaldTrump
# Out:
# User(_api=<tweepy.api.API object at 0x000000000581B608>, _json={'id': 25073877, 'id_str': '25073877', 'name': 'Donald J. Trump', 'screen_name': 'realDonaldTrump', 'location': 'Washington, DC', 'profile_location': None, 'description': '45th President of the United States of America🇺🇸', 'url': 'https://t.co/OMxB0x7xC5', 'entities': {'url': {'urls': [{'url': 'https://t.co/OMxB0x7xC5', 'expanded_url': 'http://www.Instagram.com/realDonaldTrump', 'display_url': 'Instagram.com/realDonaldTrump', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 64264552, 'friends_count': 47, 'listed_count': 108461, 'created_at': 'Wed Mar 18 13:46:38 +0000 2009', 'favourites_count': 6, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 44264, 'lang': None, 'status': {'created_at': 'Fri Sep 13 22:35:26 +0000 2019', 'id': 1172639954985455616, 'id_str': '1172639954985455616', 'text': 'While I like the Vaping alternative to Cig
# ...

# %%
type(realDonaldTrump)
# Out:
# tweepy.models.User

# %%
vars(realDonaldTrump)
# Out:
# {'_api': <tweepy.api.API at 0x581b608>,
#  '_json': {'id': 25073877,
#   'id_str': '25073877',
#   'name': 'Donald J. Trump',
#   'screen_name': 'realDonaldTrump',
#   'location': 'Washington, DC',
#   'profile_location': None,
#   'description': '45th President of the United States of America🇺🇸',
#   'url': 'https://t.co/OMxB0x7xC5',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/OMxB0x7xC5',
#       'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#       'display_url': 'Instagram.com/realDonaldTrump',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 64264552,
#   'friends_count': 47,
#   'listed_count': 108461,
#   'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#   'favourites_count': 6,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 44264,
#   'lang': None,
#   'status': {'created_at': 'Fri Sep 13 22:35:26 +0000 2019',
# ...

# %%
vars(api.get_user('narendramodi'))
# Out:
# {'_api': <tweepy.api.API at 0x581b608>,
#  '_json': {'id': 18839785,
#   'id_str': '18839785',
#   'name': 'Narendra Modi',
#   'screen_name': 'narendramodi',
#   'location': 'India',
#   'profile_location': None,
#   'description': 'Prime Minister of India',
#   'url': 'https://t.co/zzYhUUfq6i',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/zzYhUUfq6i',
#       'expanded_url': 'http://www.narendramodi.in',
#       'display_url': 'narendramodi.in',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 50068645,
#   'friends_count': 2228,
#   'listed_count': 24441,
#   'created_at': 'Sat Jan 10 17:18:56 +0000 2009',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 24533,
#   'lang': None,
#   'status': {'created_at': 'Fri Sep 13 12:38:01 +0000 2019',
#    'id': 1172489610640818176,
#    'id_str': '1172489610640818176',
# ...

# %%
vars(api.get_user('BarackObama'))
# Out:
# {'_api': <tweepy.api.API at 0x581b608>,
#  '_json': {'id': 813286,
#   'id_str': '813286',
#   'name': 'Barack Obama',
#   'screen_name': 'BarackObama',
#   'location': 'Washington, DC',
#   'profile_location': None,
#   'description': 'Dad, husband, President, citizen.',
#   'url': 'https://t.co/93Y27HEnnX',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/93Y27HEnnX',
#       'expanded_url': 'https://www.obama.org/',
#       'display_url': 'obama.org',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 108459840,
#   'friends_count': 612083,
#   'listed_count': 228726,
#   'created_at': 'Mon Mar 05 22:08:25 +0000 2007',
#   'favourites_count': 11,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 15678,
#   'lang': None,
#   'status': {'created_at': 'Thu Sep 12 18:10:20 +0000 2019',
#    'id': 1172210852415643650,
# ...

# %%
for handle in ('narendramodi', 'BarackObama', 'realDonaldTrump'):
    h = vars(api.get_user(handle))
    print(handle, h['followers_count'], h['created_at'],  h['location'])
# Out:
# narendramodi 50068775 2009-01-10 17:18:56 India
# BarackObama 108459966 2007-03-05 22:08:25 Washington, DC
# realDonaldTrump 64264862 2009-03-18 13:46:38 Washington, DC

# %%
results = api.search_users('raveena', 1000)
for each_result in results:
    print(vars(each_result)['screen_name'], vars(each_result)['location'])
# Out:
# raveena_aurora New York
# ravzangel Earth..now
# TandonRaveena Planet Earth
# raveena116 chennai
# hobi_twtt 𝚑𝚘𝚙𝚎 𝚠𝚘𝚛𝚕𝚍 | 𝚜𝚘𝚙𝚎
# RGhattaura
# ayeshakhann023 Uttar Pradesh, India
# RaveenaKaur_
# RaveenaPatel Miami, FL
# veena2er Canada
# RaveenaTheBoxer London
# RaveenaAgarwaal 🇮🇳
# RaveenaRihal
# RaveenaEmm
# FadedDiamond_ Indian Gyal 🦋✨
# raveena_radio Dudley / Manchester
# RaveenaRaviFC Heart ❤
# ravkaay Toronto, Ontario
# ravcho4 Vancouver, British Columbia
# ayee_raveena

# %%
results = api.search_users('raveena', 1000)
for each_result in results:
    location = vars(each_result)['location']
    if not 'in' in location.lower():
        print(vars(each_result)['screen_name'], vars(each_result)['location'])
# Out:
# raveena_aurora New York
# ravzangel Earth..now
# TandonRaveena Planet Earth
# raveena116 chennai
# hobi_twtt 𝚑𝚘𝚙𝚎 𝚠𝚘𝚛𝚕𝚍 | 𝚜𝚘𝚙𝚎
# RGhattaura
# RaveenaKaur_
# RaveenaPatel Miami, FL
# veena2er Canada
# RaveenaTheBoxer London
# RaveenaAgarwaal 🇮🇳
# RaveenaRihal
# RaveenaEmm
# raveena_radio Dudley / Manchester
# RaveenaRaviFC Heart ❤
# ravkaay Toronto, Ontario
# ravcho4 Vancouver, British Columbia
# ayee_raveena

# %%
results = api.favorites('realDonaldTrump')

# %%
type(results)
# Out:
# tweepy.models.ResultSet

# %%
api.trends_available()
# Out:
# [{'name': 'Worldwide',
#   'placeType': {'code': 19, 'name': 'Supername'},
#   'url': 'http://where.yahooapis.com/v1/place/1',
#   'parentid': 0,
#   'country': '',
#   'woeid': 1,
#   'countryCode': None},
#  {'name': 'Winnipeg',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 2972,
#   'countryCode': 'CA'},
#  {'name': 'Ottawa',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3369,
#   'countryCode': 'CA'},
#  {'name': 'Quebec',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3444',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3444,
#   'countryCode': 'CA'},
#  {'name': 'Montreal',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3534',
# ...

# %%
# To list all trend locations
for ech in api.trends_available():
    print(ech['name'])
# Out:
# Worldwide
# Winnipeg
# Ottawa
# Quebec
# Montreal
# Toronto
# Edmonton
# Calgary
# Vancouver
# Birmingham
# Blackpool
# Bournemouth
# Brighton
# Bristol
# Cardiff
# Coventry
# Derby
# Edinburgh
# Glasgow
# Hull
# Leeds
# Leicester
# Liverpool
# Manchester
# Middlesbrough
# Newcastle
# Nottingham
# Plymouth
# Portsmouth
# Preston
# Sheffield
# Stoke-on-Trent
# Swansea
# London
# Belfast
# Santo Domingo
# Guatemala City
# Acapulco
# Aguascalientes
# Chihuahua
# Mexico City
# Ciudad Juarez
# Nezahualcóyotl
# Culiacán
# Ecatepec de Morelos
# Guadalajara
# Hermosillo
# León
# Mérida
# Mexicali
# Monterrey
# Morelia
# Naucalpan de Juárez
# Puebla
# Querétaro
# Saltillo
# San Luis Potosí
# Tijuana
# Toluca
# Zapopan
# Mendoza
# Santiago
# Concepcion
# Valparaiso
# Bogotá
# Cali
# Medellín
# Barranquilla
# Quito
# Guayaquil
# Caracas
# Maracaibo
# Maracay
# Valencia
# Barcelona
# Ciudad Guayana
# Turmero
# Lima
# Brasília
# Belém
# Belo Horizonte
# Curitiba
# Porto Alegre
# Recife
# ...

# %%
for ech in api.trends_available():
    if ech['name'] == 'Zurich':
        print(ech)
# Out:
# {'name': 'Zurich', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/784794', 'parentid': 23424957, 'country': 'Switzerland', 'woeid': 784794, 'countryCode': 'CH'}

# %%
api.trends_place('784794')
# Out:
# [{'trends': [{'name': '#srfArena',
#     'url': 'http://twitter.com/search?q=%23srfArena',
#     'promoted_content': None,
#     'query': '%23srfArena',
#     'tweet_volume': None},
#    {'name': '#demokratiefestival',
#     'url': 'http://twitter.com/search?q=%23demokratiefestival',
#     'promoted_content': None,
#     'query': '%23demokratiefestival',
#     'tweet_volume': None},
#    {'name': 'Friday the 13th',
#     'url': 'http://twitter.com/search?q=%22Friday+the+13th%22',
#     'promoted_content': None,
#     'query': '%22Friday+the+13th%22',
#     'tweet_volume': 701761},
#    {'name': '#propagandalive',
#     'url': 'http://twitter.com/search?q=%23propagandalive',
#     'promoted_content': None,
#     'query': '%23propagandalive',
#     'tweet_volume': 15368},
#    {'name': '#gcsfc',
#     'url': 'http://twitter.com/search?q=%23gcsfc',
#     'promoted_content': None,
#     'query': '%23gcsfc',
#     'tweet_volume': None},
#    {'name': '#fibawc',
# ...

# %%
for ech in api.trends_available():
    if ech['name'] == 'Zurich':
        print(ech)
# Out:
# {'name': 'Zurich', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/784794', 'parentid': 23424957, 'country': 'Switzerland', 'woeid': 784794, 'countryCode': 'CH'}

# %%
vars(api.geo_id('df51dec6f4ee2b2c'))
# Out:
# {'_api': <tweepy.api.API at 0x581b608>,
#  'id': 'df51dec6f4ee2b2c',
#  'url': 'https://api.twitter.com/1.1/geo/id/df51dec6f4ee2b2c.json',
#  'place_type': 'neighborhood',
#  'name': 'Presidio',
#  'full_name': 'Presidio, San Francisco',
#  'country_code': 'US',
#  'country': 'United States',
#  'contained_within': [Place(_api=<tweepy.api.API object at 0x000000000581B608>, id='5a110d312052166f', url='https://api.twitter.com/1.1/geo/id/5a110d312052166f.json', place_type='city', name='San Francisco', full_name='San Francisco, CA', country_code='US', country='United States', centroid=[-122.4461400159226, 37.759828999999996], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000000000581B608>, type='Polygon', coordinates=[[[-122.514926, 37.708075], [-122.514926, 37.833238], [-122.357031, 37.833238], [-122.357031, 37.708075], [-122.514926, 37.708075]]]), attributes={})],
#  'geometry': None,
#  'polylines': [],
#  'centroid': [-122.46598425785236, 37.79989625],
# ...

# %%
vars(api.reverse_geocode(30, 40)[0])
# Out:
# {'_api': <tweepy.api.API at 0x581b608>,
#  'id': '011572c14ae5418b',
#  'url': 'https://api.twitter.com/1.1/geo/id/011572c14ae5418b.json',
#  'place_type': 'admin',
#  'name': 'Jouf',
#  'full_name': 'Jouf, Kingdom of Saudi Arabia',
#  'country_code': 'SA',
#  'country': 'Kingdom of Saudi Arabia',
#  'contained_within': [Place(_api=<tweepy.api.API object at 0x000000000581B608>, id='08b2d74428e2ca88', url='https://api.twitter.com/1.1/geo/id/08b2d74428e2ca88.json', place_type='country', name='Kingdom of Saudi Arabia', full_name='Kingdom of Saudi Arabia', country_code='SA', country='Kingdom of Saudi Arabia', centroid=[44.56510712588738, 24.259922349999997], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000000000581B608>, type='Polygon', coordinates=[[[34.567591, 16.3590225], [34.567591, 32.1608222], [55.6666671, 32.1608222], [55.6666671, 16.3590225], [34.567591, 16.3590225]]]), attributes={})],
#  'centroid': [39.794502256763124, 29.92967115],
# ...

# %%
vars(api.reverse_geocode(22, 77)[0])
# Out:
# {'_api': <tweepy.api.API at 0x581b608>,
#  'id': '159a141cad06f102',
#  'url': 'https://api.twitter.com/1.1/geo/id/159a141cad06f102.json',
#  'place_type': 'admin',
#  'name': 'मध्य प्रदेश',
#  'full_name': 'मध्य प्रदेश, भारत',
#  'country_code': 'IN',
#  'country': 'भारत',
#  'contained_within': [Place(_api=<tweepy.api.API object at 0x000000000581B608>, id='b850c1bfd38f30e0', url='https://api.twitter.com/1.1/geo/id/b850c1bfd38f30e0.json', place_type='country', name='भारत', full_name='भारत', country_code='IN', country='भारत', centroid=[79.91569416233017, 20.568453], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000000000581B608>, type='Polygon', coordinates=[[[67.997691, 6.622513], [67.997691, 33.254896], [97.170672, 33.254896], [97.170672, 6.622513], [67.997691, 6.622513]]]), attributes={})],
#  'centroid': [79.39450972641997, 23.970895],
# ...
