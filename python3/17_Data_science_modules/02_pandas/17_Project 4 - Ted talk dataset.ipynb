# %%
# https://www.kaggle.com/rounakbanik/ted-data-analysis
import pandas as pd

df = pd.read_csv("../../datasets/ted_main.csv")
df.head(3)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
# 2  TED2006  1140739200         26   David Pogue
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
# 2              David Pogue: Simplicity sells            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
#
#                                        related_talks    speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...       Author/educator
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...      Climate advocate
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...  Technology columnist
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
#
#                          title  \
# 0  Do schools kill creativity?
# 1  Averting the climate crisis
# 2             Simplicity sells
#
#                                                  url     views
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292

# %%
# print out the columns
df.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views'],
#       dtype='object')

# %%
# reorder the columns
df = df[
    [
        "name",
        "title",
        "description",
        "main_speaker",
        "speaker_occupation",
        "num_speaker",
        "duration",
        "event",
        "film_date",
        "published_date",
        "comments",
        "tags",
        "languages",
        "ratings",
        "related_talks",
        "url",
        "views",
    ]
]
df.head(3)
# Out:
#                                         name                        title  \
# 0  Ken Robinson: Do schools kill creativity?  Do schools kill creativity?
# 1       Al Gore: Averting the climate crisis  Averting the climate crisis
# 2              David Pogue: Simplicity sells             Simplicity sells
#
#                                          description  main_speaker  \
# 0  Sir Ken Robinson makes an entertaining and pro...  Ken Robinson
# 1  With the same humor and humanity he exuded in ...       Al Gore
# 2  New York Times columnist David Pogue takes aim...   David Pogue
#
#      speaker_occupation  num_speaker  duration    event   film_date  \
# 0       Author/educator            1      1164  TED2006  1140825600
# 1      Climate advocate            1       977  TED2006  1140825600
# 2  Technology columnist            1      1286  TED2006  1140739200
#
#    published_date  comments  \
# 0      1151367060      4553
# 1      1151367060       265
# 2      1151367060       124
#
#                                                 tags  languages  \
# 0  ['children', 'creativity', 'culture', 'dance',...         60
# 1  ['alternative energy', 'cars', 'climate change...         43
# 2  ['computers', 'entertainment', 'interface desi...         26
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
#
#                                                  url     views
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292

# %%
# change from epoc time to human readable datetime
import datetime

df["film_date"] = df["film_date"].apply(
    lambda x: datetime.datetime.fromtimestamp(int(x)).strftime("%d-%m-%Y")
)
df["film_date"].head(3)
# Out:
# 0    25-02-2006
# 1    25-02-2006
# 2    24-02-2006
# Name: film_date, dtype: object

# %%
df["published_date"] = df["published_date"].apply(
    lambda x: datetime.datetime.fromtimestamp(int(x)).strftime("%d-%m-%Y")
)
df["published_date"].head(3)
# Out:
# 0    27-06-2006
# 1    27-06-2006
# 2    27-06-2006
# Name: published_date, dtype: object

# %%
df.head(3)
# Out:
#                                         name                        title  \
# 0  Ken Robinson: Do schools kill creativity?  Do schools kill creativity?
# 1       Al Gore: Averting the climate crisis  Averting the climate crisis
# 2              David Pogue: Simplicity sells             Simplicity sells
#
#                                          description  main_speaker  \
# 0  Sir Ken Robinson makes an entertaining and pro...  Ken Robinson
# 1  With the same humor and humanity he exuded in ...       Al Gore
# 2  New York Times columnist David Pogue takes aim...   David Pogue
#
#      speaker_occupation  num_speaker  duration    event   film_date  \
# 0       Author/educator            1      1164  TED2006  25-02-2006
# 1      Climate advocate            1       977  TED2006  25-02-2006
# 2  Technology columnist            1      1286  TED2006  24-02-2006
#
#   published_date  comments                                               tags  \
# 0     27-06-2006      4553  ['children', 'creativity', 'culture', 'dance',...
# 1     27-06-2006       265  ['alternative energy', 'cars', 'climate change...
# 2     27-06-2006       124  ['computers', 'entertainment', 'interface desi...
#
#    languages                                            ratings  \
# 0         60  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1         43  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2         26  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
#
#                                                  url     views
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292

# %%
# how many row in this dataframe
df.shape
# Out:
# (2550, 17)

# %%
# what is 5 most viewed talks of all time
pop_talks = df.sort_values("views", ascending=False)[["title", "main_speaker", "views"]]
pop_talks.head(5)
# Out:
#                                          title  main_speaker     views
# 0                  Do schools kill creativity?  Ken Robinson  47227110
# 1346  Your body language may shape who you are     Amy Cuddy  43155405
# 677           How great leaders inspire action   Simon Sinek  34309432
# 837                 The power of vulnerability   Brené Brown  31168150
# 452     10 things you didn't know about orgasm    Mary Roach  22270883

# %%
df["views"].describe()
# Out:
# count    2.550000e+03
# mean     1.698297e+06
# std      2.498479e+06
# min      5.044300e+04
# 25%      7.557928e+05
# 50%      1.124524e+06
# 75%      1.700760e+06
# max      4.722711e+07
# Name: views, dtype: float64

# %%
df["comments"].describe()
# Out:
# count    2550.000000
# mean      191.562353
# std       282.315223
# min         2.000000
# 25%        63.000000
# 50%       118.000000
# 75%       221.750000
# max      6404.000000
# Name: comments, dtype: float64

# %%
# %matplotlib inline
import seaborn as sns

sns.distplot(df["comments"])
# Out:
# /Users/tanpv/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# analyse ted talk on month and year
# separate the month column
month_order = [
    "Jan",
    "Feb",
    "Mar",
    "Apr",
    "May",
    "Jun",
    "Jul",
    "Aug",
    "Sep",
    "Oct",
    "Nov",
    "Dec",
]
df["month"] = df["film_date"].apply(lambda x: month_order[int(x.split("-")[1]) - 1])
df["month"].head(10)
# Out:
# 0    Feb
# 1    Feb
# 2    Feb
# 3    Feb
# 4    Feb
# 5    Feb
# 6    Feb
# 7    Feb
# 8    Feb
# 9    Feb
# Name: month, dtype: object

# %%
month_df = pd.DataFrame(df["month"].value_counts()).reset_index()
month_df.columns = ["month", "talks"]
month_df.head(3)
# Out:
#   month  talks
# 0   Feb    601
# 1   Mar    397
# 2   Jun    270

# %%
sns.barplot(x="month", y="talks", data=month_df, order=month_order)

# %%
df["year"] = df["film_date"].apply(lambda x: x.split("-")[2])
df["year"].head(3)
# Out:
# 0    2006
# 1    2006
# 2    2006
# Name: year, dtype: object

# %%
year_df = pd.DataFrame(df["year"].value_counts().reset_index())
year_df.columns = ["year", "talks"]
year_df.head(3)
# Out:
#    year  talks
# 0  2013    270
# 1  2011    270
# 2  2010    267

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 5))
sns.pointplot(x="year", y="talks", data=year_df)

# %%
# what about main speaker
df.groupby("main_speaker").count()
# Out:
#                              name  title  description  speaker_occupation  \
# main_speaker
#  OK Go                          1      1            1                   1
#  Rodrigo y Gabriela             1      1            1                   1
#  Silk Road Ensemble             1      1            1                   1
#  Sofi Tukker                    1      1            1                   1
# AJ Jacobs                       3      3            3                   3
# Aakash Odedra                   1      1            1                   1
# Aala El-Khani                   1      1            1                   1
# Aaron Huey                      1      1            1                   1
# Aaron Koblin                    1      1            1                   1
# Aaron O'Connell                 1      1            1                   1
# Abe Davis                       1      1            1                   1
# Abha Dawesar                    1      1            1                   1
# Abigail Marsh                   1      1            1                   1
# Abigail Washburn                1      1            1                   1
# Abraham Verghese                1      1            1                   1
# Achenyo Idachaba                1      1            1                   1
# Adam Alter                      1      1            1                   1
# Adam Davidson                   1      1            1                   1
# Adam Driver                     1      1            1                   1
# Adam Foss                       1      1            1                   1
# Adam Galinsky                   1      1            1                   1
# Adam Garone                     1      1            1                   1
# Adam Grant                      2      2            2                   2
# Adam Grosser                    1      1            1                   1
# Adam Ostrow                     1      1            1                   1
# Adam Sadowsky                   1      1            1                   1
# Adam Savage                     3      3            3                   3
# Adam Spencer                    1      1            1                   1
# Adam de la Zerda                1      1            1                   1
# Aditi Gupta                     1      1            1                   1
# ...                           ...    ...          ...                 ...
# Woody Norris                    1      1            1                   1
# Xavier Vilalta                  1      1            1                   1
# Yang Lan                        1      1            1                   1
# Yanis Varoufakis                1      1            1                   1
# Yann Arthus-Bertrand            1      1            1                   1
# Yann Dall'Aglio                 1      1            1                   1
# Yasheng Huang                   1      1            1                   1
# Yassmin Abdel-Magied            1      1            1                   1
# Yoav Medan                      1      1            1                   1
# Yochai Benkler                  1      1            1                   1
# Yoruba Richen                   1      1            1                   1
# Yossi Vardi                     1      1            1                   1
# Young-ha Kim                    1      1            1                   1
# Yuval Noah Harari               2      2            2                   2
# Yves Behar                      2      2            2                   2
# Yves Morieux                    2      2            2                   2
# Yves Rossy                      1      1            1                   1
# Zach Kaplan + Keith Schacht     1      1            1                   1
# Zahra' Langhi                   1      1            1                   1
# Zainab Salbi                    1      1            1                   1
# Zak Ebrahim                     1      1            1                   1
# Zaria Forman                    1      1            1                   1
# Ze Frank                        3      3            3                   3
# Zeresenay Alemseged             1      1            1                   1
# Zeynep Tufekci                  2      2            2                   2
# Ziauddin Yousafzai              1      1            1                   1
# Ziyah Gafić                    1      1            1                   1
# Zubaida Bai                     1      1            1                   1
# eL Seed                         2      2            2                   2
# iO Tillett Wright               1      1            1                   1
#
#                              num_speaker  duration  event  film_date  \
# main_speaker
#  OK Go                                 1         1      1          1
#  Rodrigo y Gabriela                    1         1      1          1
#  Silk Road Ensemble                    1         1      1          1
#  Sofi Tukker                           1         1      1          1
# AJ Jacobs                              3         3      3          3
# Aakash Odedra                          1         1      1          1
# Aala El-Khani                          1         1      1          1
# Aaron Huey                             1         1      1          1
# Aaron Koblin                           1         1      1          1
# Aaron O'Connell                        1         1      1          1
# Abe Davis                              1         1      1          1
# Abha Dawesar                           1         1      1          1
# Abigail Marsh                          1         1      1          1
# Abigail Washburn                       1         1      1          1
# Abraham Verghese                       1         1      1          1
# Achenyo Idachaba                       1         1      1          1
# Adam Alter                             1         1      1          1
# Adam Davidson                          1         1      1          1
# Adam Driver                            1         1      1          1
# Adam Foss                              1         1      1          1
# Adam Galinsky                          1         1      1          1
# Adam Garone                            1         1      1          1
# Adam Grant                             2         2      2          2
# Adam Grosser                           1         1      1          1
# Adam Ostrow                            1         1      1          1
# Adam Sadowsky                          1         1      1          1
# Adam Savage                            3         3      3          3
# Adam Spencer                           1         1      1          1
# Adam de la Zerda                       1         1      1          1
# Aditi Gupta                            1         1      1          1
# ...                                  ...       ...    ...        ...
# Woody Norris                           1         1      1          1
# Xavier Vilalta                         1         1      1          1
# Yang Lan                               1         1      1          1
# Yanis Varoufakis                       1         1      1          1
# Yann Arthus-Bertrand                   1         1      1          1
# Yann Dall'Aglio                        1         1      1          1
# Yasheng Huang                          1         1      1          1
# Yassmin Abdel-Magied                   1         1      1          1
# Yoav Medan                             1         1      1          1
# Yochai Benkler                         1         1      1          1
# Yoruba Richen                          1         1      1          1
# Yossi Vardi                            1         1      1          1
# Young-ha Kim                           1         1      1          1
# Yuval Noah Harari                      2         2      2          2
# Yves Behar                             2         2      2          2
# Yves Morieux                           2         2      2          2
# Yves Rossy                             1         1      1          1
# Zach Kaplan + Keith Schacht            1         1      1          1
# Zahra' Langhi                          1         1      1          1
# Zainab Salbi                           1         1      1          1
# Zak Ebrahim                            1         1      1          1
# Zaria Forman                           1         1      1          1
# Ze Frank                               3         3      3          3
# Zeresenay Alemseged                    1         1      1          1
# Zeynep Tufekci                         2         2      2          2
# Ziauddin Yousafzai                     1         1      1          1
# Ziyah Gafić                           1         1      1          1
# Zubaida Bai                            1         1      1          1
# eL Seed                                2         2      2          2
# iO Tillett Wright                      1         1      1          1
#
#                              published_date  comments  tags  languages  \
# main_speaker
#  OK Go                                    1         1     1          1
#  Rodrigo y Gabriela                       1         1     1          1
#  Silk Road Ensemble                       1         1     1          1
#  Sofi Tukker                              1         1     1          1
# AJ Jacobs                                 3         3     3          3
# Aakash Odedra                             1         1     1          1
# Aala El-Khani                             1         1     1          1
# Aaron Huey                                1         1     1          1
# Aaron Koblin                              1         1     1          1
# Aaron O'Connell                           1         1     1          1
# Abe Davis                                 1         1     1          1
# Abha Dawesar                              1         1     1          1
# Abigail Marsh                             1         1     1          1
# Abigail Washburn                          1         1     1          1
# Abraham Verghese                          1         1     1          1
# Achenyo Idachaba                          1         1     1          1
# Adam Alter                                1         1     1          1
# Adam Davidson                             1         1     1          1
# Adam Driver                               1         1     1          1
# Adam Foss                                 1         1     1          1
# Adam Galinsky                             1         1     1          1
# Adam Garone                               1         1     1          1
# Adam Grant                                2         2     2          2
# Adam Grosser                              1         1     1          1
# Adam Ostrow                               1         1     1          1
# Adam Sadowsky                             1         1     1          1
# Adam Savage                               3         3     3          3
# Adam Spencer                              1         1     1          1
# Adam de la Zerda                          1         1     1          1
# Aditi Gupta                               1         1     1          1
# ...                                     ...       ...   ...        ...
# Woody Norris                              1         1     1          1
# Xavier Vilalta                            1         1     1          1
# Yang Lan                                  1         1     1          1
# Yanis Varoufakis                          1         1     1          1
# Yann Arthus-Bertrand                      1         1     1          1
# Yann Dall'Aglio                           1         1     1          1
# Yasheng Huang                             1         1     1          1
# Yassmin Abdel-Magied                      1         1     1          1
# Yoav Medan                                1         1     1          1
# Yochai Benkler                            1         1     1          1
# Yoruba Richen                             1         1     1          1
# Yossi Vardi                               1         1     1          1
# Young-ha Kim                              1         1     1          1
# Yuval Noah Harari                         2         2     2          2
# Yves Behar                                2         2     2          2
# Yves Morieux                              2         2     2          2
# Yves Rossy                                1         1     1          1
# Zach Kaplan + Keith Schacht               1         1     1          1
# Zahra' Langhi                             1         1     1          1
# Zainab Salbi                              1         1     1          1
# Zak Ebrahim                               1         1     1          1
# Zaria Forman                              1         1     1          1
# Ze Frank                                  3         3     3          3
# Zeresenay Alemseged                       1         1     1          1
# Zeynep Tufekci                            2         2     2          2
# Ziauddin Yousafzai                        1         1     1          1
# Ziyah Gafić                              1         1     1          1
# Zubaida Bai                               1         1     1          1
# eL Seed                                   2         2     2          2
# iO Tillett Wright                         1         1     1          1
#
#                              ratings  related_talks  url  views  month  year
# main_speaker
#  OK Go                             1              1    1      1      1     1
#  Rodrigo y Gabriela                1              1    1      1      1     1
#  Silk Road Ensemble                1              1    1      1      1     1
#  Sofi Tukker                       1              1    1      1      1     1
# AJ Jacobs                          3              3    3      3      3     3
# Aakash Odedra                      1              1    1      1      1     1
# Aala El-Khani                      1              1    1      1      1     1
# Aaron Huey                         1              1    1      1      1     1
# Aaron Koblin                       1              1    1      1      1     1
# Aaron O'Connell                    1              1    1      1      1     1
# Abe Davis                          1              1    1      1      1     1
# Abha Dawesar                       1              1    1      1      1     1
# Abigail Marsh                      1              1    1      1      1     1
# Abigail Washburn                   1              1    1      1      1     1
# Abraham Verghese                   1              1    1      1      1     1
# Achenyo Idachaba                   1              1    1      1      1     1
# Adam Alter                         1              1    1      1      1     1
# Adam Davidson                      1              1    1      1      1     1
# Adam Driver                        1              1    1      1      1     1
# Adam Foss                          1              1    1      1      1     1
# Adam Galinsky                      1              1    1      1      1     1
# Adam Garone                        1              1    1      1      1     1
# Adam Grant                         2              2    2      2      2     2
# Adam Grosser                       1              1    1      1      1     1
# Adam Ostrow                        1              1    1      1      1     1
# Adam Sadowsky                      1              1    1      1      1     1
# Adam Savage                        3              3    3      3      3     3
# Adam Spencer                       1              1    1      1      1     1
# Adam de la Zerda                   1              1    1      1      1     1
# Aditi Gupta                        1              1    1      1      1     1
# ...                              ...            ...  ...    ...    ...   ...
# Woody Norris                       1              1    1      1      1     1
# Xavier Vilalta                     1              1    1      1      1     1
# Yang Lan                           1              1    1      1      1     1
# Yanis Varoufakis                   1              1    1      1      1     1
# Yann Arthus-Bertrand               1              1    1      1      1     1
# Yann Dall'Aglio                    1              1    1      1      1     1
# Yasheng Huang                      1              1    1      1      1     1
# Yassmin Abdel-Magied               1              1    1      1      1     1
# Yoav Medan                         1              1    1      1      1     1
# Yochai Benkler                     1              1    1      1      1     1
# Yoruba Richen                      1              1    1      1      1     1
# Yossi Vardi                        1              1    1      1      1     1
# Young-ha Kim                       1              1    1      1      1     1
# Yuval Noah Harari                  2              2    2      2      2     2
# Yves Behar                         2              2    2      2      2     2
# Yves Morieux                       2              2    2      2      2     2
# Yves Rossy                         1              1    1      1      1     1
# Zach Kaplan + Keith Schacht        1              1    1      1      1     1
# Zahra' Langhi                      1              1    1      1      1     1
# Zainab Salbi                       1              1    1      1      1     1
# Zak Ebrahim                        1              1    1      1      1     1
# Zaria Forman                       1              1    1      1      1     1
# Ze Frank                           3              3    3      3      3     3
# Zeresenay Alemseged                1              1    1      1      1     1
# Zeynep Tufekci                     2              2    2      2      2     2
# Ziauddin Yousafzai                 1              1    1      1      1     1
# Ziyah Gafić                       1              1    1      1      1     1
# Zubaida Bai                        1              1    1      1      1     1
# eL Seed                            2              2    2      2      2     2
# iO Tillett Wright                  1              1    1      1      1     1
#
# [2156 rows x 18 columns]
