# %% [markdown]
# # FTP  - file Transfer Protocol

# %%
import ftplib

# %%
# Connecting to an FTP Server
ftp = ftplib.FTP('ftp.dlptest.com')
ftp.login('dlpuser', 'rNrKYTX9g7z3RgJRmxWuGHbeu')
print(ftp.getwelcome())
ftp.quit()
# Out:
# 220 Welcome to the DLP Test FTP Server
# '221 Goodbye.'

# %%
# Listing Files in a Directory
ftp = ftplib.FTP('ftp.dlptest.com')
ftp.login('dlpuser', 'rNrKYTX9g7z3RgJRmxWuGHbeu')
files = ftp.nlst()
print(files)
ftp.quit()
# Out:
# ['10.101.1.2_20250130-18023512_IVA.jpg', '10.101.1.2_20250130-18024072_IVA.jpg', '10.101.1.2_20250130-18024893_IVA.jpg', '10.101.1.2_20250130-18030874_IVA.jpg', '_11473798', '_11477637', '_11477663', 'ftp_test_file_10MB', 'upload-Y1ghCa0mZvQgF7KFkQ3jd7mCpRmTbPrTBmtgmdOC1T1FMyIr0m']
# '221 Goodbye.'

# %%
# Downloading a File
with open('10.101.1.2_20250130-18023512_IVA.jpg', 'wb') as local_file:
    ftp.retrbinary('RETR 10.101.1.2_20250130-18023512_IVA.jpg', local_file.write)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Downloading a File
#       2 with open('10.101.1.2_20250130-18023512_IVA.jpg', 'wb') as local_file:
# ----> 3     ftp.retrbinary('RETR 10.101.1.2_20250130-18023512_IVA.jpg', local_file.write)
#
# File /usr/local/python/3.12.1/lib/python3.12/ftplib.py:435, in FTP.retrbinary(self, cmd, callback, blocksize, rest)
#     421 def retrbinary(self, cmd, callback, blocksize=8192, rest=None):
#     422     """Retrieve data in binary mode.  A new port is created for you.
#     423
#     424     Args:
#    (...)
#     433       The response code.
#     434     """
# --> 435     self.voidcmd('TYPE I')
#     436     with self.transfercmd(cmd, rest) as conn:
#     437         while data := conn.recv(blocksize):
#
# File /usr/local/python/3.12.1/lib/python3.12/ftplib.py:285, in FTP.voidcmd(self, cmd)
# ...

# %%
with open('local_file.txt', 'rb') as local_file:
    ftp.storbinary('STOR remote_file.txt', local_file)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 with open('local_file.txt', 'rb') as local_file:
# ----> 2     ftp.storbinary('STOR remote_file.txt', local_file)
#
# File /usr/local/python/3.12.1/lib/python3.12/ftplib.py:494, in FTP.storbinary(self, cmd, fp, blocksize, callback, rest)
#     479 def storbinary(self, cmd, fp, blocksize=8192, callback=None, rest=None):
#     480     """Store a file in binary mode.  A new port is created for you.
#     481
#     482     Args:
#    (...)
#     492       The response code.
#     493     """
# --> 494     self.voidcmd('TYPE I')
#     495     with self.transfercmd(cmd, rest) as conn:
#     496         while buf := fp.read(blocksize):
#
# File /usr/local/python/3.12.1/lib/python3.12/ftplib.py:285, in FTP.voidcmd(self, cmd)
#     283 def voidcmd(self, cmd):
# ...
