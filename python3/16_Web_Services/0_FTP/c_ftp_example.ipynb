# %%
import ftplib

# %%
import ftplib

ftp = ftplib.FTP('ftp.adobe.com')
ftp.login()  # Assuming anonymous access
print(ftp.getwelcome())
ftp.quit()
# Out:
# 220 Welcome to Adobe FTP services
# '221 Goodbye.'

# %%
# List files in directory
import ftplib

ftp = ftplib.FTP('ftp.adobe.com')
ftp.login()  # Assuming anonymous access
files = ftp.nlst()  # List files in the current directory
print(files)
ftp.quit()
# Out:
# ['Acrobat', 'Broker', 'Broker.link', 'Web_Users_Click_Here.html', 'alm_support', 'armdl-test.txt', 'bin', 'dev', 'docs', 'filetest.txt', 'ftp', 'jp', 'jul15_2019', 'lbtest.txt', 'lib', 'license.txt', 'pub', 'pub-archive', 'pushtest', 'signon.txt', 'usr', 'vvishnu-test.html', 'zoomtest.html']
# '221 Goodbye.'

# %%
# 

import ftplib

ftp = ftplib.FTP('ftp.adobe.com')
ftp.login()  # Assuming anonymous access

with open('downloaded_file.txt', 'wb') as local_file:
    ftp.retrbinary('RETR remote_file.txt', local_file.write)  # Replace with actual file name

ftp.quit()
# Out:
# ---------------------------------------------------------------------------
# error_perm                                Traceback (most recent call last)
# Cell In[4], line 9
#       6 ftp.login()  # Assuming anonymous access
#       8 with open('downloaded_file.txt', 'wb') as local_file:
# ----> 9     ftp.retrbinary('RETR remote_file.txt', local_file.write)  # Replace with actual file name
#      11 ftp.quit()
#
# File /usr/local/python/3.12.1/lib/python3.12/ftplib.py:436, in FTP.retrbinary(self, cmd, callback, blocksize, rest)
#     422 """Retrieve data in binary mode.  A new port is created for you.
#     423
#     424 Args:
#    (...)
#     433   The response code.
#     434 """
#     435 self.voidcmd('TYPE I')
# --> 436 with self.transfercmd(cmd, rest) as conn:
#     437     while data := conn.recv(blocksize):
#     438         callback(data)
#
# File /usr/local/python/3.12.1/lib/python3.12/ftplib.py:393, in FTP.transfercmd(self, cmd, rest)
# ...

# %%
import ftplib

ftp = ftplib.FTP('ftp.adobe.com')
ftp.login()  # Assuming anonymous access

# List files in the current directory
files = ftp.nlst()
print("Available files:", files)

ftp.quit()
# Out:
# Available files: ['Acrobat', 'Broker', 'Broker.link', 'Web_Users_Click_Here.html', 'alm_support', 'armdl-test.txt', 'bin', 'dev', 'docs', 'filetest.txt', 'ftp', 'jp', 'jul15_2019', 'lbtest.txt', 'lib', 'license.txt', 'pub', 'pub-archive', 'pushtest', 'signon.txt', 'usr', 'vvishnu-test.html', 'zoomtest.html']
# '221 Goodbye.'

# %%
import ftplib

ftp = ftplib.FTP('ftp.adobe.com')
ftp.login()  # Assuming anonymous access

# Use a valid file name from the previous step
valid_file_name = 'armdl-test.txt'  # Replace with the correct file name

with open('downloaded_file.txt', 'wb') as local_file:
    ftp.retrbinary(f'RETR {valid_file_name}', local_file.write)

ftp.quit()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 import ftplib
# ----> 3 ftp = ftplib.FTP('ftp.adobe.com')
#       4 ftp.login()  # Assuming anonymous access
#       6 # Use a valid file name from the previous step
#
# File /usr/local/python/3.12.1/lib/python3.12/ftplib.py:121, in FTP.__init__(self, host, user, passwd, acct, timeout, source_address, encoding)
#     119 self.timeout = timeout
#     120 if host:
# --> 121     self.connect(host)
#     122     if user:
#     123         self.login(user, passwd, acct)
#
# File /usr/local/python/3.12.1/lib/python3.12/ftplib.py:162, in FTP.connect(self, host, port, timeout, source_address)
#     160 self.af = self.sock.family
#     161 self.file = self.sock.makefile('r', encoding=self.encoding)
# --> 162 self.welcome = self.getresp()
#     163 return self.welcome
#
# ...
