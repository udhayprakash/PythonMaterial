# %% [markdown]
# ## time magicblock

# %%
2**128
# Out:
# 340282366920938463463374607431768211456

# %%
# %time 2**128
# Out:
# Wall time: 0 ns
# 340282366920938463463374607431768211456

# %%
n = 1000000
# %time sum(range(n))
# Out:
# Wall time: 51 ms
# 499999500000

# %%
# %time print('hello world')
# Out:
# hello world
# Wall time: 0 ns

# %%
# %time 3**999
# Out:
# Wall time: 0 ns
# ...

# %%
# %time 3**999999
# Out:
# Wall time: 97 ms
# ...

# %% [markdown]
# ## timeit magicblock

# %%
# %timeit pass
# Out:
# 11.9 ns ± 1.09 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
u = None
# %timeit u is None
# Out:
# 51.6 ns ± 3.74 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit -r 4 u == None
# Out:
# 59.3 ns ± 1.55 ns per loop (mean ± std. dev. of 4 runs, 10000000 loops each)

# %%
import time

# %timeit -n1 time.sleep(2)
# Out:
# 2 s ± 234 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit sum(range(100))
# Out:
# 1.92 µs ± 133 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %%timeit
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# 404 ms ± 33.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import random

L = [random.random() for i in range(100000)]
# %timeit L.sort()
# Out:
# 2.17 ms ± 359 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%time
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# Wall time: 418 ms

# %% [markdown]
# further reference: https://jakevdp.github.io/PythonDataScienceHandbook/01.07-timing-and-profiling.html

# %%
s = "udhay"
t = "prakash"

# %timeit f'{s} {t}'                              # 782.ns
# Out:
# 91.6 ns ± 0.237 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit s + ' ' + t                             # 104 ns
# Out:
# 106 ns ± 0.893 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit ' '.join((s,t))                         # 135 ns
# Out:
# 136 ns ± 48.2 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit '%s %s'%(s,t)                           # 188 ns
# Out:
# 199 ns ± 1.83 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit '{} {}'.format(s,t)                     # 283 ns
# Out:
# 238 ns ± 4.2 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
from string import Template

# %%
# %timeit Template('$s $t').substitute(s=s, t=t)  # 898 ns
# Out:
# 2 µs ± 34.7 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
import timeit

# %%
timeit.timeit("[(a, b) for a in (1, 3, 5) for b in (2, 4, 6)]")
# Out:
# 0.6599774000005709

# %%
timeit.timeit("[(a, b) for a in (1, 3, 5) for b in (2, 4, 6)]", number=1000)
# Out:
# 0.0014043000010133255

# %%
timeit.repeat("[(a, b) for a in (1, 3, 5) for b in (2, 4, 6)]")
# Out:
# [0.672638600000937,
#  0.6489672000006976,
#  0.6558292000008805,
#  0.6575391000005766,
#  0.654230699999971]

# %%
min(timeit.repeat("[(a, b) for a in (1, 3, 5) for b in (2, 4, 6)]"))
# Out:
# 0.642582600001333

# %%
import cProfile

cProfile.run("[(a, b) for a in (1, 3, 5) for b in (2, 4, 6)]")
# Out:
#          4 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# ```
# ncalls:
#     the number of times that particular function was called
#     This number may actually be written as a fraction (e.g. 3/1) where the first value is
#     the number of total calls and the second value is the number of primitive calls (not recursive).
#
# tottime:
#     the total amount of time the function spent executing not including calls to subfunctions
#
# percall (first):
#     the ratio of tottime to ncalls (i.e. the average amount of time spent in this function excluding subfunctions)
#
# cumtime:
#     the total amount of time the function spent executing including calls to subfunctions
#
# percall (second):
#     the ratio of cumtime to primitive calls (i.e. the average amount of time spent in this function)
#
# filename:
#     lineno(function): the filename, line number, and function in question
# ```
