# %%
import psutil

# %%
print(dir(psutil))
# Out:
# ['ABOVE_NORMAL_PRIORITY_CLASS', 'AF_LINK', 'AIX', 'AccessDenied', 'BELOW_NORMAL_PRIORITY_CLASS', 'BSD', 'CONN_CLOSE', 'CONN_CLOSE_WAIT', 'CONN_CLOSING', 'CONN_DELETE_TCB', 'CONN_ESTABLISHED', 'CONN_FIN_WAIT1', 'CONN_FIN_WAIT2', 'CONN_LAST_ACK', 'CONN_LISTEN', 'CONN_NONE', 'CONN_SYN_RECV', 'CONN_SYN_SENT', 'CONN_TIME_WAIT', 'Error', 'FREEBSD', 'HIGH_PRIORITY_CLASS', 'IDLE_PRIORITY_CLASS', 'IOPRIO_HIGH', 'IOPRIO_LOW', 'IOPRIO_NORMAL', 'IOPRIO_VERYLOW', 'LINUX', 'MACOS', 'NETBSD', 'NIC_DUPLEX_FULL', 'NIC_DUPLEX_HALF', 'NIC_DUPLEX_UNKNOWN', 'NORMAL_PRIORITY_CLASS', 'NoSuchProcess', 'OPENBSD', 'OSX', 'POSIX', 'POWER_TIME_UNKNOWN', 'POWER_TIME_UNLIMITED', 'PermissionError', 'Popen', 'Process', 'ProcessLookupError', 'REALTIME_PRIORITY_CLASS', 'STATUS_DEAD', 'STATUS_DISK_SLEEP', 'STATUS_IDLE', 'STATUS_LOCKED', 'STATUS_PARKED', 'STATUS_RUNNING', 'STATUS_SLEEPING', 'STATUS_STOPPED', 'STATUS_TRACING_STOP', 'STATUS_WAITING', 'STATUS_WAKING', 'STATUS_ZOMBIE', 'SUNOS', 'TimeoutExpired', 'WINDOWS', 'ZombieProcess', '_LOWEST_PID', '_PY3', '_SENTINEL', '_TOTAL_PHYMEM', '__all__', '__author__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_as_dict_attrnames', '_assert_pid_not_reused', '_common', '_compat', '_cpu_busy_time', '_cpu_times_deltas', '_cpu_tot_time', '_last_cpu_times', '_last_cpu_times_2', '_last_per_cpu_times', '_last_per_cpu_times_2', '_lock', '_pmap', '_ppid_map', '_pprint_secs', '_psplatform', '_psutil_windows', '_pswindows', '_timer', '_wrap_numbers', 'boot_time', 'collections', 'contextlib', 'cpu_count', 'cpu_freq', 'cpu_percent', 'cpu_stats', 'cpu_times', 'cpu_times_percent', 'datetime', 'disk_io_counters', 'disk_partitions', 'disk_usage', 'functools', 'getloadavg', 'long', 'net_connections', 'net_if_addrs', 'net_if_stats', 'net_io_counters', 'os', 'pid_exists', 'pids', 'process_iter', 'pwd', 'sensors_battery', 'signal', 'subprocess', 'swap_memory', 'sys', 'test', 'threading', 'time', 'users', 'version_info', 'virtual_memory', 'wait_procs', 'win_service_get', 'win_service_iter']

# %%
print(f''' 
    {psutil.LINUX   =}
    {psutil.MACOS   =}
    {psutil.NETBSD  =}
    {psutil.FREEBSD =}
    {psutil.AIX     =}
    {psutil.BSD     =}
    {psutil.OPENBSD =}
    {psutil.OSX     =}
    {psutil.POSIX   =}
    {psutil.WINDOWS =}
    {psutil.SUNOS   =}

''')
# Out:
#
#     psutil.LINUX   =False
#     psutil.MACOS   =False
#     psutil.NETBSD  =False
#     psutil.FREEBSD =False
#     psutil.AIX     =False
#     psutil.BSD     =False
#     psutil.OPENBSD =False
#     psutil.OSX     =False
#     psutil.POSIX   =False
#     psutil.WINDOWS =True
#     psutil.SUNOS   =False

# %%
psutil.cpu_times() # returns system CPU times as a named tuple
# Out:
# scputimes(user=60980.03124999999, system=50272.796875, idle=449823.65625, interrupt=3289.5, dpc=5329.09375)

# %% [markdown]
# ```
#     Parameters:
#
#         user – time spent by normal processes executing in user mode
#         system – time spent by processes executing in kernel mode
#         idle – time when system was idle
#         nice – time spent by priority processes executing in user mode
#         iowait – time spent waiting for I/O to complete. This is not accounted in idle time counter.
#         irq – time spent for servicing hardware interrupts
#         softirq – time spent for servicing software interrupts
#         steal – time spent by other operating systems running in a virtualized environment
#         guest – time spent running a virtual CPU for guest operating systems under the control of the Linux kernel
# ```

# %%
psutil.cpu_percent(interval=1)
# Out:
# 44.8

# %%
print("Number of cores in system           :", psutil.cpu_count(logical=True)) 
print("Number of physical cores in system  :",psutil.cpu_count(logical=False))
# Out:
# Number of cores in system           : 8
# Number of physical cores in system  : 4

# %% [markdown]
# - Logical core is calculated as the number of physical cores multiplied by the number of threads that can run on each core.
# - In the absence of logical core, it only counts a number of physical cores.

# %%
print("CPU Statistics", psutil.cpu_stats())
# Out:
# CPU Statistics scpustats(ctx_switches=1652747976, interrupts=1121804585, soft_interrupts=0, syscalls=1563003690)

# %% [markdown]
# ```
#     ctx_switches    – number of context switches since boot.
#     interrupts      – number of interrupts since boot.
#     soft_interrupts – number of software interrupts since boot.
#     syscalls        – number of system calls since boot. Always set to 0 in Ubuntu.
# ```

# %%
psutil.cpu_freq()
# Out:
# scpufreq(current=1600.0, min=0.0, max=1800.0)

# %% [markdown]
#  - a tuple that includes current, min and max frequencies expressed in Mhz.
#  - on ubuntu current frequency reports the real-time value. Whereas on all other platforms it represents the nominal “fixed” value.

# %%
psutil.getloadavg()
# Out:
# (0.0, 0.0, 0.0)

# %% [markdown]
# - This function gives the average system load in last 1, 5 and 15 minutes as a tuple.
# - The load represents the processes which are in a runnable state, either using the CPU or waiting to use the CPU (e.g. waiting for disk I/O).

# %%
psutil.virtual_memory()
# Out:
# svmem(total=8464355328, available=2428428288, percent=71.3, used=6035927040, free=2428428288)

# %% [markdown]
# - gives system memory usage in bytes.
# - The sum of used and available may or may not be equal to total.
# - In order to get details of free physical memory this function is used.
# ```
#     Parameters:
#
#     total     – total physical memory excluding swap.
#     available – the memory that can be given instantly to processes without the system going into swap.
#     used      – memory used.
#     free      – memory not used at and is readily available
#     active    – memory currently in use or very recently used.
#     inactive  – memory that is marked as not used.
#     buffers   – cache data like file system metadata.
#     cached    – cached data
#     shared    – memory that may be accessed by multiple processes.
# ```

# %%
psutil.swap_memory()
# Out:
# sswap(total=19738644480, used=12517470208, free=7221174272, percent=63.4, sin=0, sout=0)

# %% [markdown]
# This function provides details of swap memory statistics as a tuple.
#
# ```
# Parameters:
#     total   – total swap memory in bytes
#     used    – used swap memory in bytes
#     free    – free swap memory in bytes
#     percent – the percentage usage that is calculated as (total – available) / total * 100
#     sin     – the number of bytes the system has swapped in from disk
#     sout    – the number of bytes the system has swapped out from disk
# ```

# %%
psutil.disk_partitions()
# Out:
# [sdiskpart(device='C:\\', mountpoint='C:\\', fstype='NTFS', opts='rw,fixed'),
#  sdiskpart(device='D:\\', mountpoint='D:\\', fstype='NTFS', opts='rw,fixed')]

# %% [markdown]
# - This function provides the details of all mounted disk partitions as a list of tuples including device, mount point and filesystem type.

# %%
psutil.disk_usage('/') # any path
# Out:
# sdiskusage(total=1000187359232, used=454434111488, free=545753247744, percent=45.4)

# %% [markdown]
# - This function gives disk usage statistics as a tuple for a given path. Total, used and free space are expressed in bytes, along with the percentage usage.

# %%
psutil.net_io_counters()
# Out:
# snetio(bytes_sent=47860708, bytes_recv=55553329, packets_sent=317039, packets_recv=151547, errin=0, errout=0, dropin=0, dropout=0)

# %% [markdown]
# - This function gives the details of network Input output statistics as a tuple.
#
# ```
#     Parameters:
#
#         bytes_sent   – number of bytes sent
#         bytes_recv   – number of bytes received
#         packets_sent – number of packets sent
#         packets_recv – number of packets received
#         errin        – total number of errors while receiving
#         errout       – total number of errors while sending
#         dropin       – total number of incoming packets which were dropped
#         dropout      – total number of outgoing packets which were dropped
# ```

# %%
for each_connection in psutil.net_connections():
    print(each_connection, '\n\n')
# Out:
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54593), raddr=addr(ip='182.1.223.91', port=60682), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53329), raddr=addr(ip='3.113.183.58', port=443), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54220), raddr=addr(ip='185.45.195.154', port=20153), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54807), raddr=addr(ip='122.118.3.207', port=45228), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=56574), raddr=addr(ip='13.33.183.76', port=443), status='CLOSE_WAIT', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='192.168.43.65', port=53464), raddr=(), status='NONE', pid=12708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4070:4294:cdaf:9252:42da:691:c116', port=37579), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='172.29.32.1', port=4369), raddr=addr(ip='172.29.32.1', port=54150), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54683), raddr=addr(ip='115.98.51.222', port=65272), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64974), raddr=addr(ip='127.0.0.1', port=65032), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54749), raddr=addr(ip='114.79.47.171', port=3562), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='0.0.0.0', port=59058), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:9b:9ee4:4cea:3c6:93d8:5631', port=45403), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='172.29.32.1', port=37897), raddr=(), status='NONE', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54307), raddr=addr(ip='81.166.254.153', port=22491), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54730), raddr=addr(ip='127.0.0.1', port=64978), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:2e81:15d4:5db1:2c6a:8e46:7d5a', port=40253), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64978), raddr=(), status='LISTEN', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=51553), raddr=addr(ip='65.93.37.86', port=12303), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54796), raddr=addr(ip='182.1.160.252', port=58657), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='127.0.0.1', port=49665), raddr=(), status='NONE', pid=5208)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54693), raddr=addr(ip='197.210.64.209', port=24624), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64975), raddr=(), status='LISTEN', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=65040), raddr=addr(ip='127.0.0.1', port=65039), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='0.0.0.0', port=5040), raddr=(), status='LISTEN', pid=864)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54705), raddr=addr(ip='34.201.170.70', port=57632), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54746), raddr=addr(ip='103.138.222.129', port=16762), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='0.0.0.0', port=808), raddr=(), status='LISTEN', pid=3996)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=61210), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=63181), raddr=(), status='NONE', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=5353), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=65039), raddr=addr(ip='127.0.0.1', port=65040), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4070:4e00:398f:3717:199d:f5d8:8995', port=46497), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54645), raddr=addr(ip='197.210.65.133', port=3723), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54346), raddr=addr(ip='177.158.131.79', port=53492), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=56304), raddr=addr(ip='151.101.153.2', port=80), status='ESTABLISHED', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54709), raddr=addr(ip='77.219.14.142', port=51732), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54072), raddr=addr(ip='154.204.53.42', port=52917), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=65036), raddr=addr(ip='127.0.0.1', port=65037), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='::', port=33060), raddr=(), status='LISTEN', pid=5920)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54672), raddr=addr(ip='106.217.200.3', port=43518), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=6771), raddr=(), status='NONE', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54714), raddr=addr(ip='77.125.48.216', port=6881), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54584), raddr=addr(ip='144.48.161.45', port=34083), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54651), raddr=addr(ip='197.253.66.228', port=26131), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2401:4900:35ff:3a1:6aa:f3ca:eb6:6db6', port=45245), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=5353), raddr=(), status='NONE', pid=26292)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=55989), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54779), raddr=addr(ip='127.0.0.1', port=54778), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54378), raddr=addr(ip='14.202.74.183', port=58706), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=52626), raddr=addr(ip='51.38.57.40', port=27115), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54743), raddr=addr(ip='107.159.87.8', port=11663), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4071:200c:3913::11b1:b8a1', port=21061), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:4594:2397::2823:c0a4', port=40947), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54317), raddr=addr(ip='114.79.55.120', port=28168), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='172.29.32.1', port=4369), raddr=addr(ip='172.29.32.1', port=54590), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54065), raddr=addr(ip='77.219.9.48', port=28670), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=50184), raddr=addr(ip='127.0.0.1', port=50183), status='ESTABLISHED', pid=19432)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54729), raddr=addr(ip='127.0.0.1', port=64974), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54787), raddr=addr(ip='127.0.0.1', port=54786), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54181), raddr=addr(ip='197.210.47.7', port=38706), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2405:204:5014:f9e1:457:370a:a85:c956', port=37015), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53819), raddr=addr(ip='69.171.250.60', port=443), status='ESTABLISHED', pid=7968)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64975), raddr=addr(ip='127.0.0.1', port=54731), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54044), raddr=addr(ip='197.210.65.82', port=41881), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54772), raddr=addr(ip='127.0.0.1', port=54771), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54296), raddr=addr(ip='182.1.183.252', port=49360), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=52197), raddr=addr(ip='2404:6800:4009:80f::2004', port=443), status='ESTABLISHED', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54711), raddr=addr(ip='77.219.14.14', port=52465), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:10a:7f8::3ad:c0a0', port=45365), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54665), raddr=addr(ip='27.97.128.108', port=51413), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2401:4900:328c:6edd:220a:ea93:255:3308', port=39134), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='0.0.0.0', port=49667), raddr=(), status='LISTEN', pid=1688)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54788), raddr=addr(ip='127.0.0.1', port=54789), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=51915), raddr=addr(ip='2404:6800:4007:804::200e', port=443), status='ESTABLISHED', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54399), raddr=addr(ip='197.253.66.13', port=6907), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64978), raddr=addr(ip='127.0.0.1', port=64985), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64976), raddr=addr(ip='127.0.0.1', port=65041), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54755), raddr=addr(ip='176.230.191.230', port=12115), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='0.0.0.0', port=49668), raddr=(), status='LISTEN', pid=3564)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54203), raddr=addr(ip='104.211.158.212', port=443), status='LAST_ACK', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54791), raddr=addr(ip='127.0.0.1', port=54790), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=55936), raddr=addr(ip='216.58.197.42', port=443), status='CLOSE_WAIT', pid=23668)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54703), raddr=addr(ip='74.118.186.210', port=443), status='SYN_SENT', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54675), raddr=addr(ip='47.29.251.116', port=30166), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54804), raddr=addr(ip='177.23.60.36', port=49701), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64980), raddr=addr(ip='127.0.0.1', port=64979), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2401:4900:49ac:89cf::82d:1ecc', port=33253), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2401:4900:4bb6:34fe:e200:4ed1:6a92:11a6', port=46572), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::1', port=49664), raddr=(), status='NONE', pid=5284)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54610), raddr=addr(ip='185.21.216.198', port=60429), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53511), raddr=addr(ip='94.21.95.161', port=45377), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54125), raddr=addr(ip='73.120.172.193', port=41467), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=56575), raddr=addr(ip='13.33.183.76', port=443), status='CLOSE_WAIT', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=65037), raddr=addr(ip='127.0.0.1', port=65036), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54391), raddr=addr(ip='197.210.65.230', port=25769), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=8888), raddr=addr(ip='127.0.0.1', port=54738), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54701), raddr=addr(ip='67.86.12.68', port=6881), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=2177), raddr=(), status='NONE', pid=14480)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54637), raddr=addr(ip='84.39.140.231', port=37848), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54623), raddr=addr(ip='178.50.235.99', port=53722), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54189), raddr=addr(ip='47.29.235.234', port=60353), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53538), raddr=addr(ip='85.247.111.218', port=15674), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=50182), raddr=addr(ip='127.0.0.1', port=50181), status='ESTABLISHED', pid=19432)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54747), raddr=addr(ip='103.143.100.26', port=59917), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4072:78c:77a3:a221:ce51:3f25:7c2', port=38407), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54055), raddr=addr(ip='71.84.206.32', port=27879), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='fe80::91db:9761:b58f:a962', port=37897), raddr=(), status='NONE', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54688), raddr=addr(ip='66.203.125.12', port=443), status='SYN_SENT', pid=19432)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54663), raddr=addr(ip='204.102.74.31', port=51848), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53853), raddr=addr(ip='74.118.186.210', port=443), status='FIN_WAIT1', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=500), raddr=(), status='NONE', pid=3988)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=53953), raddr=addr(ip='2404:6800:4009:808::2006', port=443), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54723), raddr=addr(ip='157.44.55.45', port=52325), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='::1', port=37897), raddr=(), status='LISTEN', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:2195:ca60::27ca:90b0', port=44172), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54722), raddr=addr(ip='157.44.125.199', port=38691), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54326), raddr=addr(ip='114.79.55.82', port=52748), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=53788), raddr=addr(ip='2404:6800:4009:80e::2002', port=443), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53513), raddr=addr(ip='80.244.30.126', port=40106), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='0.0.0.0', port=5353), raddr=(), status='NONE', pid=5352)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54689), raddr=addr(ip='172.67.140.59', port=8080), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='127.0.0.1', port=59429), raddr=(), status='NONE', pid=20428)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54161), raddr=addr(ip='182.1.178.252', port=58657), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::1', port=1900), raddr=(), status='NONE', pid=12708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54717), raddr=addr(ip='77.137.146.160', port=8664), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54184), raddr=addr(ip='197.210.47.29', port=49971), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53506), raddr=addr(ip='79.136.3.28', port=38609), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:441b:8e56::247d:80a0', port=41563), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54280), raddr=addr(ip='52.196.63.169', port=443), status='FIN_WAIT1', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54803), raddr=addr(ip='176.67.199.9', port=44473), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2401:4900:4b37:af51::e28:2784', port=36739), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54770), raddr=addr(ip='127.0.0.1', port=54769), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54144), raddr=addr(ip='182.1.169.213', port=62936), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54211), raddr=addr(ip='197.95.144.65', port=28242), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=53781), raddr=addr(ip='127.0.0.1', port=53780), status='ESTABLISHED', pid=19432)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=37897), raddr=(), status='LISTEN', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54638), raddr=addr(ip='106.77.183.252', port=39957), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='::', port=49666), raddr=(), status='LISTEN', pid=1852)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54707), raddr=addr(ip='91.110.236.64', port=28170), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='0.0.0.0', port=49390), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=52421), raddr=addr(ip='13.33.179.97', port=443), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54745), raddr=addr(ip='182.1.179.121', port=64118), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2401:4900:22ac:9647:25c:e6fd:2a0d:bb7e', port=44317), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54768), raddr=addr(ip='127.0.0.1', port=54767), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54782), raddr=addr(ip='127.0.0.1', port=54783), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:4504:5dd6:6cba:d2a3:ec50:8585', port=38285), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54646), raddr=addr(ip='103.242.238.89', port=41641), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54650), raddr=addr(ip='197.253.66.183', port=6476), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53161), raddr=addr(ip='216.58.203.163', port=443), status='ESTABLISHED', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54567), raddr=addr(ip='139.0.81.66', port=49207), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53988), raddr=addr(ip='182.1.175.222', port=59793), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4070:421d:73be:c18:31bf:b3c2:d0cc', port=40236), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4070:20b:4ccc:b734:1124:b5f9:af42', port=36605), status='SYN_RECV', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54635), raddr=addr(ip='13.33.179.173', port=443), status='ESTABLISHED', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54764), raddr=addr(ip='127.0.0.1', port=54763), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54783), raddr=addr(ip='127.0.0.1', port=54782), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=8888), raddr=addr(ip='127.0.0.1', port=64989), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54583), raddr=addr(ip='47.29.244.60', port=44975), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54673), raddr=addr(ip='182.1.179.27', port=54922), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64974), raddr=addr(ip='127.0.0.1', port=54729), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=57057), raddr=addr(ip='151.101.152.238', port=443), status='ESTABLISHED', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54780), raddr=addr(ip='127.0.0.1', port=54781), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=57005), raddr=addr(ip='13.33.169.100', port=443), status='CLOSE_WAIT', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54758), raddr=addr(ip='127.0.0.1', port=54757), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=57893), raddr=addr(ip='2404:6800:4007:812::200a', port=443), status='CLOSE_WAIT', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='::1', port=8888), raddr=(), status='LISTEN', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='0.0.0.0', port=445), raddr=(), status='LISTEN', pid=4)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='127.0.0.1', port=53465), raddr=(), status='NONE', pid=12708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4070:2098:15bd::1da1:98a0', port=48075), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54565), raddr=addr(ip='114.79.55.80', port=6881), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54310), raddr=addr(ip='182.1.173.209', port=60860), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54090), raddr=addr(ip='197.210.64.184', port=11619), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4072:513:8b79:192f:55ac:831:106b', port=37303), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54575), raddr=addr(ip='103.49.55.46', port=6881), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54763), raddr=addr(ip='127.0.0.1', port=54764), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54191), raddr=addr(ip='197.210.47.111', port=62348), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64986), raddr=addr(ip='127.0.0.1', port=64987), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=58109), raddr=addr(ip='52.217.89.164', port=443), status='CLOSE_WAIT', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54757), raddr=addr(ip='127.0.0.1', port=54758), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=50167), raddr=addr(ip='127.0.0.1', port=50166), status='ESTABLISHED', pid=17980)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53913), raddr=addr(ip='110.137.103.237', port=24177), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64972), raddr=addr(ip='127.0.0.1', port=64973), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:2100:3f84:d8a6:cb47:6147:cd29', port=41100), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54649), raddr=addr(ip='197.210.64.28', port=63079), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54190), raddr=addr(ip='54.230.91.23', port=443), status='ESTABLISHED', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='0.0.0.0', port=61210), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=49671), raddr=addr(ip='127.0.0.1', port=49670), status='ESTABLISHED', pid=5920)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53489), raddr=addr(ip='69.254.28.37', port=29195), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54177), raddr=addr(ip='197.210.64.152', port=41015), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64974), raddr=(), status='LISTEN', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53926), raddr=addr(ip='185.37.121.204', port=1), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54652), raddr=addr(ip='104.232.71.216', port=17105), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54375), raddr=addr(ip='84.26.32.252', port=42088), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=65033), raddr=addr(ip='127.0.0.1', port=65034), status='ESTABLISHED', pid=14800)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54777), raddr=addr(ip='127.0.0.1', port=54776), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='::', port=135), raddr=(), status='LISTEN', pid=1260)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4070:220c:137b:7ae2:adb5:2b46:d44e', port=40437), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2402:8100:21f6:7b4e:e592:2e64:ae3:cb62', port=42519), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='172.29.32.1', port=1900), raddr=(), status='NONE', pid=12708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54644), raddr=addr(ip='89.205.108.66', port=43908), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=49390), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='0.0.0.0', port=63181), raddr=(), status='NONE', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54162), raddr=addr(ip='182.1.178.228', port=58657), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=52292), raddr=addr(ip='93.152.155.254', port=54800), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54716), raddr=addr(ip='89.44.217.149', port=32583), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='0.0.0.0', port=49665), raddr=(), status='LISTEN', pid=988)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54786), raddr=addr(ip='127.0.0.1', port=54787), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=53612), raddr=addr(ip='2404:6800:4007:80f::2002', port=443), status='ESTABLISHED', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='0.0.0.0', port=15672), raddr=(), status='LISTEN', pid=5048)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='127.0.0.1', port=59428), raddr=(), status='NONE', pid=20428)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54319), raddr=addr(ip='114.125.183.77', port=59906), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54647), raddr=addr(ip='197.210.64.57', port=52601), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=52621), raddr=addr(ip='197.95.144.65', port=28242), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54696), raddr=addr(ip='69.160.96.26', port=20104), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::1', port=53462), raddr=(), status='NONE', pid=12708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54694), raddr=addr(ip='62.44.138.178', port=51049), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54771), raddr=addr(ip='127.0.0.1', port=54772), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='fe80::e539:e10f:606d:277b', port=2177), raddr=(), status='NONE', pid=14480)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2401:4900:2085:c04c:1:2:bf53:6677', port=39993), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='0.0.0.0', port=49666), raddr=(), status='LISTEN', pid=1852)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:2d3a:94f:d414:28cb:3587:75da', port=55101), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54797), raddr=addr(ip='114.79.55.247', port=56147), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2401:4900:4cca:45f0:ce86:508c:8f20:2a7', port=45051), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=49670), raddr=addr(ip='127.0.0.1', port=49671), status='ESTABLISHED', pid=5920)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54095), raddr=addr(ip='77.219.11.244', port=57766), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54555), raddr=addr(ip='182.1.208.71', port=56266), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54286), raddr=addr(ip='114.125.165.224', port=61597), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54643), raddr=addr(ip='197.210.64.145', port=16756), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54680), raddr=addr(ip='114.125.170.90', port=58516), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54695), raddr=addr(ip='94.49.133.59', port=30546), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='::', port=445), raddr=(), status='LISTEN', pid=4)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2401:4900:27d2:2a4b:7187:1b9:60c8:a498', port=45309), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=50185), raddr=addr(ip='127.0.0.1', port=50186), status='ESTABLISHED', pid=19432)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54058), raddr=addr(ip='77.219.10.106', port=63397), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=52240), raddr=addr(ip='13.33.179.66', port=443), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54653), raddr=addr(ip='207.11.73.201', port=39799), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54685), raddr=addr(ip='182.1.188.193', port=2049), status='SYN_SENT', pid=1708)
#
#
# ...
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54600), raddr=addr(ip='112.133.253.109', port=58485), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=58110), raddr=addr(ip='52.217.89.164', port=443), status='CLOSE_WAIT', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=59058), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='0.0.0.0', port=5355), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=54776), raddr=addr(ip='127.0.0.1', port=54777), status='ESTABLISHED', pid=23272)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54529), raddr=addr(ip='62.44.138.131', port=44401), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54100), raddr=addr(ip='197.210.65.84', port=14392), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4070:208e:6906:d5ac:1f94:b096:bf3', port=43751), status='SYN_RECV', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=50160), raddr=addr(ip='127.0.0.1', port=50161), status='ESTABLISHED', pid=17980)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=58038), raddr=addr(ip='74.125.130.108', port=993), status='ESTABLISHED', pid=23668)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=50183), raddr=addr(ip='127.0.0.1', port=50184), status='ESTABLISHED', pid=19432)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54715), raddr=addr(ip='85.153.202.121', port=59801), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=5353), raddr=(), status='NONE', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4070:2087:fa:c29e:9f2e:a479:be28', port=47031), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=51882), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2405:204:568e:deea:5d85:85c5:c716:e67b', port=56339), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54756), raddr=addr(ip='52.114.128.43', port=443), status='SYN_SENT', pid=3912)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=54364), raddr=addr(ip='2603:1046:700:34::2', port=443), status='ESTABLISHED', pid=19020)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54639), raddr=addr(ip='197.210.47.125', port=49160), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:4499:2a37::25ec:c0a0', port=37613), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='::', port=808), raddr=(), status='LISTEN', pid=3996)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53421), raddr=addr(ip='60.142.202.178', port=12334), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=57002), raddr=addr(ip='13.33.169.100', port=443), status='CLOSE_WAIT', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=64488), raddr=addr(ip='109.255.96.88', port=6882), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=57510), raddr=addr(ip='104.18.15.165', port=443), status='ESTABLISHED', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2409:4070:4e19:e27d:42d5:f6e2:8290:80d7', port=60828), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54620), raddr=addr(ip='23.200.49.33', port=443), status='ESTABLISHED', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2401:4900:4aa9:bc03:f3d9:5f7:e4fd:77be', port=40413), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='::', port=3306), raddr=(), status='LISTEN', pid=5920)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54806), raddr=addr(ip='176.240.160.110', port=27089), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='fe80::91db:9761:b58f:a962', port=5353), raddr=(), status='NONE', pid=4972)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54213), raddr=addr(ip='58.179.197.111', port=19066), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', port=37897), raddr=addr(ip='2001:8f8:1325:dc8d:15c3:5d4c:54a1:4736', port=48879), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54201), raddr=addr(ip='104.232.65.84', port=45448), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54754), raddr=addr(ip='112.200.227.98', port=29477), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=56341), raddr=addr(ip='142.250.76.67', port=80), status='CLOSE_WAIT', pid=4068)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='0.0.0.0', port=500), raddr=(), status='NONE', pid=3988)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54642), raddr=addr(ip='74.75.108.4', port=39888), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53848), raddr=addr(ip='74.118.186.210', port=443), status='TIME_WAIT', pid=0)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=6341), raddr=(), status='LISTEN', pid=19432)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=53226), raddr=addr(ip='2404:6800:4003:c02::bd', port=443), status='ESTABLISHED', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=53776), raddr=addr(ip='127.0.0.1', port=53777), status='ESTABLISHED', pid=19432)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='127.0.0.1', port=5353), raddr=(), status='NONE', pid=4972)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=54374), raddr=addr(ip='2001:8f8:1329:3e6c:3925:378c:7629:62a7', port=35845), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54744), raddr=addr(ip='157.44.10.72', port=57850), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=65126), raddr=addr(ip='124.197.16.161', port=28197), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54099), raddr=addr(ip='197.210.65.124', port=8002), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54571), raddr=addr(ip='5.178.65.246', port=443), status='ESTABLISHED', pid=5420)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54320), raddr=addr(ip='77.219.9.77', port=11755), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54671), raddr=addr(ip='182.1.180.201', port=2049), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='0.0.0.0', port=49725), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=53780), raddr=addr(ip='127.0.0.1', port=53781), status='ESTABLISHED', pid=19432)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54312), raddr=addr(ip='182.1.202.133', port=54978), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4070:2e01:ae2:582e:b0d1:1fda:7948', port=49212), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2401:4900:4bc5:477b:2114:eaf6:c75a:2c2f', port=42109), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54682), raddr=addr(ip='102.142.7.79', port=43690), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54164), raddr=addr(ip='182.1.187.217', port=60353), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54697), raddr=addr(ip='91.232.208.224', port=54701), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=57426), raddr=addr(ip='2603:1046:700:21::2', port=443), status='ESTABLISHED', pid=23668)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='::', port=49664), raddr=(), status='LISTEN', pid=884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53990), raddr=addr(ip='186.204.178.208', port=16570), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='fe80::e539:e10f:606d:277b', port=37897), raddr=(), status='NONE', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54551), raddr=addr(ip='182.1.220.22', port=53549), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='::', port=49725), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='0.0.0.0', port=49313), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='fe80::e539:e10f:606d:277b', port=53460), raddr=(), status='NONE', pid=12708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='0.0.0.0', port=58366), raddr=(), status='NONE', pid=2884)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54163), raddr=addr(ip='182.1.183.145', port=51748), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54740), raddr=addr(ip='159.69.115.200', port=6881), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54802), raddr=addr(ip='182.1.178.91', port=63822), status='SYN_SENT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4072:78c:77a3:a221:ce51:3f25:7c2', port=40769), status='FIN_WAIT1', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=37897), raddr=addr(ip='2409:4070:17:18d2:1de8:6c84:d60b:b60f', port=36291), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53970), raddr=addr(ip='84.26.32.252', port=42088), status='LAST_ACK', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET6: 23>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', port=51758), raddr=addr(ip='2001:16a2:4d05:be00::1', port=45493), status='CLOSE_WAIT', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='127.0.0.1', port=1900), raddr=(), status='NONE', pid=12708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=54564), raddr=addr(ip='45.95.98.80', port=50080), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='172.29.32.1', port=2177), raddr=(), status='NONE', pid=14480)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='192.168.43.65', port=53578), raddr=addr(ip='109.48.171.249', port=53961), status='ESTABLISHED', pid=1708)
#
#
# sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=64975), raddr=addr(ip='127.0.0.1', port=54728), status='ESTABLISHED', pid=23272)

# %% [markdown]
# - This function gives the list of socket connections of a system as a named tuples.
# ```
#     Parameters:
#
#         fd     – the socket file descriptor.
#         family – the socket family, either AF_INET, AF_INET6 or AF_UNIX.
#         type   – the socket type, either SOCK_STREAM, SOCK_DGRAM or SOCK_SEQPACKET.
#         laddr  – the local address as a (ip, port) named tuple
#         raddr  – the remote address as a (ip, port) named tuple
#         status – represents the status of a TCP connection.
#         pid    – the PID of the process which opened the socket, if retrievable, else None.
# ```

# %%
psutil.net_if_addrs()
# Out:
# {'Local Area Connection 2': [snicaddr(family=<AddressFamily.AF_LINK: -1>, address='00-FF-62-8D-78-7E', netmask=None, broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET: 2>, address='169.254.77.69', netmask='255.255.0.0', broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET6: 23>, address='fe80::d048:939c:2b15:4d45', netmask=None, broadcast=None, ptp=None)],
#  'vEthernet (WSL)': [snicaddr(family=<AddressFamily.AF_LINK: -1>, address='00-15-5D-32-60-2A', netmask=None, broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET: 2>, address='172.29.32.1', netmask='255.255.240.0', broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET6: 23>, address='fe80::e539:e10f:606d:277b', netmask=None, broadcast=None, ptp=None)],
#  'Local Area Connection* 3': [snicaddr(family=<AddressFamily.AF_LINK: -1>, address='2A-39-26-50-28-14', netmask=None, broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET: 2>, address='169.254.123.136', netmask='255.255.0.0', broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET6: 23>, address='fe80::51bf:7a26:876:7b88', netmask=None, broadcast=None, ptp=None)],
#  'Local Area Connection* 12': [snicaddr(family=<AddressFamily.AF_LINK: -1>, address='AA-39-26-E0-70-38', netmask=None, broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET: 2>, address='169.254.182.228', netmask='255.255.0.0', broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET6: 23>, address='fe80::59c:fb9f:7a1b:b6e4', netmask=None, broadcast=None, ptp=None)],
#  'Wi-Fi': [snicaddr(family=<AddressFamily.AF_LINK: -1>, address='28-39-26-57-8E-D5', netmask=None, broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET: 2>, address='192.168.43.65', netmask='255.255.255.0', broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET6: 23>, address='2409:4070:2d3f:d0ac:91db:9761:b58f:a962', netmask=None, broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET6: 23>, address='2409:4070:2d3f:d0ac:c059:a09d:56cc:b720', netmask=None, broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET6: 23>, address='fe80::91db:9761:b58f:a962', netmask=None, broadcast=None, ptp=None)],
#  'Loopback Pseudo-Interface 1': [snicaddr(family=<AddressFamily.AF_INET: 2>, address='127.0.0.1', netmask='255.0.0.0', broadcast=None, ptp=None),
#   snicaddr(family=<AddressFamily.AF_INET6: 23>, address='::1', netmask=None, broadcast=None, ptp=None)]}

# %% [markdown]
# - This function is used to get the addresses of each network interface card installed on the system.
# - It is a dictionary whose keys are the Network Interface Card names and value is a list of named tuples for each address assigned to it.
# - Each tuple includes:
# ```
#     family     – the socket family, either AF_INET or AF_INET6
#     address    – the primary NIC address
#     netmask    – the netmask address
#     broadcast  – the broadcast address.
#     ptp        – “point to point” it is the destination address on a point to point interface.
# ```

# %%
psutil.sensors_battery()
# Out:
# sbattery(percent=78, secsleft=<BatteryTime.POWER_TIME_UNLIMITED: -2>, power_plugged=True)

# %% [markdown]
# - This function gives battery status information as a named tuple.
# ```
#     - Parameters:
#         percent       – battery power left as a percentage.
#         secsleft      – an approximate time in seconds before battery is completely discharged.
#         power_plugged – True if the AC power cable is connected, False if it is not connected
# ```

# %%
psutil.boot_time() # system boot time which is expressed in seconds since the epoch.
# Out:
# 1606719379.590315

# %%
psutil.users()
# Out:
# [suser(name='Amma', terminal=None, host=None, started=1606719388.600063, pid=None)]

# %% [markdown]
# - This function gives the list of users who are connected on the system as a named tuples.
# ```
# Parameters:
#
#     user     – It is the system name of the user.
#     terminal – the tty of the user.
#     host     – the host name of the user.
#     started  – the creation time as a floating point number expressed in seconds since the epoch.
#     pid      – the PID of the login process.
# ```
